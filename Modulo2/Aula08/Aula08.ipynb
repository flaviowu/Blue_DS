# %%
import seaborn as sns
sns.set_theme()

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips["time"].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ## 1. lmplot

# %%
g = sns.lmplot(x = "total_bill", y="tip", data=tips)

# %%
g = sns.lmplot(x = "total_bill", y="tip", hue="smoker", data=tips)

# %%
g = sns.lmplot(x = "total_bill", y="tip", hue="smoker", data=tips, markers=["o", "x"])

# %%
g = sns.lmplot(x = "total_bill", y="tip", hue="smoker", data=tips, markers=["o", "x"], palette="viridis_r")

# %%
g = sns.lmplot(x = "total_bill", y="tip", hue="smoker", data=tips, markers=["o", "x"], palette=dict(Yes="r", No="k"))

# %%
g = sns.lmplot(x = "total_bill", y="tip", col="smoker", data=tips)

# %%
g = sns.lmplot(x = "total_bill", y="tip", col="time", data=tips)

# %%
g = sns.lmplot(x = "total_bill", y="tip", col="day", data=tips)

# %%
g = sns.lmplot(x = "total_bill", y="tip", col="day", data=tips, height=6, aspect=.5, hue="day", x_jitter=5)

# %%
g = sns.lmplot(x = "total_bill", y="tip", col="day", data=tips, height=6, aspect=.5)

# %%
g = sns.lmplot(x = "total_bill", y="tip", col="day", data=tips, height=6, col_wrap=2)

# %%
g = sns.lmplot(x = "total_bill", y="tip", hue="day", data=tips)

# %% [markdown]
# # 2. regplot
# Plot data and a linear regression model fit.

# %%
import seaborn as sns; sns.set_theme(color_codes=True)
tips = sns.load_dataset("tips")
ax = sns.regplot(x="total_bill", y="tip", data=tips)

# %%
import numpy as np; np.random.seed(8)
mean, cov = [4, 6], [(1.5, .7), (.7, 1)]
x, y = np.random.multivariate_normal(mean, cov, 80).T
ax = sns.regplot(x=x, y=y, color="g")

# %%
import pandas as pd
x, y = pd.Series(x, name="x_var"), pd.Series(y, name="y_var")
ax = sns.regplot(x=x, y=y, marker="+")

# %%
ax = sns.regplot(x=x, y=y, ci=68, truncate=False)

# %%
ax = sns.regplot(x="size", y="total_bill", data=tips, x_jitter=.1)

# %%
ax = sns.regplot(x="size", y="total_bill", data=tips)

# %%
ax = sns.regplot(x="size", y="total_bill", data=tips, x_estimator=np.mean)

# %% [markdown]
# # 3. resiplot
# Plot the residuals of a linear regression.
