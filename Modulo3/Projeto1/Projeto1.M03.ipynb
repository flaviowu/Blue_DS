# %% [markdown]
# ### Projeto 1 - IBM - RH - Análise de desempenho e atritos de funcionários

# %% [markdown]
# ## IBM HR Analytics Employee Attrition & Performance - Kaggle
#
# Este conjunto de dados foi criado pela equipe de cientistas de dados da IBM com o objetivo de ser usado de maneira educacional. Iremos criar uma variável chamada de turnover (rotatividade) para ser usada como variável dependente. Esta variável demonstra que o funcionário poderá sair da empresa.

# %% [markdown]
# ### Sobre este projeto
# Os principais pontos que serão avaliados:
# - Levantamento de hipóteses
# - Manipulação de dados e criação de gráficos simples com o Pandas
# - Criar um modelo de classificação

# %% [markdown]
# ### Preparação do ambiente
# Para este projeto, acessem o link - https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset e logo abaixo cliquem em "Download". Caso voce não tenha uma conta no Kaggle, crie uma e retorne para esse ponto para realizar o download. Descompacte o arquivo.
#
# Crie a variável **turnover seguindo os passos abaixo:
#
# ```
# dados['turnover'] = dados.replace({'Attrition': {'Yes':1, 'No': 0}})
# ```

# %%
import pandas as pd

# %%
df = pd.read_csv('./WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df['Attrition'].head()
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4     No
# Name: Attrition, dtype: object

# %%
df['turnover'] = df['Attrition'].replace({'Yes':1, 'No': 0})

# %%
df.drop('Attrition', axis = 1, inplace = True)

# %%
df.columns.isin(['turnover'])
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True])

# %%
df.columns.isin(['Attrition'])
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
df['turnover'].head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: turnover, dtype: int64

# %% [markdown]
# ### Exercicio 1. (2 pontos)
# Realize uma análise sobre as variáveis independentes em relação a variável turnover. Quais ideias você obteve? Faça uma pequena apresentação de três a quatro gráficos e escreva suas percepções abaixo de cada um.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'turnover'],
#       dtype='object')

# %% [markdown]
# drop das variáveis de controle da tabela

# %%
df.drop(['EmployeeCount', 'EmployeeNumber'], axis=1, inplace=True)

# %% [markdown]
# drop de variáveis redundantes, mantendo a 'MonthlyIncome'

# %%
df.drop(['DailyRate', 'HourlyRate', 'MonthlyRate'], axis=1, inplace=True)

# %% [markdown]
# drop da variável 'Over18', pois todos os funcionários são maiores de 18 anos

# %%
df['Over18'].describe()
# Out:
# count     1470
# unique       1
# top          Y
# freq      1470
# Name: Over18, dtype: object

# %%
df.drop('Over18', axis=1, inplace=True)

# %%
df['StandardHours'].describe()
# Out:
# count    1470.0
# mean       80.0
# std         0.0
# min        80.0
# 25%        80.0
# 50%        80.0
# 75%        80.0
# max        80.0
# Name: StandardHours, dtype: float64

# %%
df.drop('StandardHours', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   object
#  2   Department                1470 non-null   object
#  3   DistanceFromHome          1470 non-null   int64
#  4   Education                 1470 non-null   int64
#  5   EducationField            1470 non-null   object
#  6   EnvironmentSatisfaction   1470 non-null   int64
#  7   Gender                    1470 non-null   object
#  8   JobInvolvement            1470 non-null   int64
#  9   JobLevel                  1470 non-null   int64
#  10  JobRole                   1470 non-null   object
#  11  JobSatisfaction           1470 non-null   int64
#  12  MaritalStatus             1470 non-null   object
#  13  MonthlyIncome             1470 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'Department', 'DistanceFromHome', 'Education',
#        'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'turnover'],
#       dtype='object')

# %%
f, ax = plt.subplots(9,3, figsize=(24,48))

sns.histplot(ax=ax[0,0], data=df, x='Age', hue='turnover');
sns.countplot(ax=ax[0,1], data=df, x='BusinessTravel', hue='turnover')
sns.countplot(ax=ax[0,2], data=df, x='Department', hue='turnover')

sns.histplot(ax=ax[1,0], data=df, x='DistanceFromHome', hue='turnover')
sns.countplot(ax=ax[1,1], data=df, x='Education', hue='turnover')
sns.countplot(ax=ax[1,2], data=df, x='EducationField', hue='turnover')

sns.countplot(ax=ax[2,0], data=df, x='EnvironmentSatisfaction', hue='turnover')
sns.countplot(ax=ax[2,1], data=df, x='Gender', hue='turnover')
sns.countplot(ax=ax[2,2], data=df, x='JobInvolvement', hue='turnover')

sns.countplot(ax=ax[3,0], data=df, x='JobLevel', hue='turnover')
sns.countplot(ax=ax[3,1], data=df, x='JobRole', hue='turnover');
sns.countplot(ax=ax[3,2], data=df, x='JobSatisfaction', hue='turnover')

sns.countplot(ax=ax[4,0], data=df, x='MaritalStatus', hue='turnover')
sns.histplot(ax=ax[4,1], data=df, x='MonthlyIncome', hue='turnover')
sns.histplot(ax=ax[4,2], data=df, x='NumCompaniesWorked', hue='turnover')

sns.countplot(ax=ax[5,0], data=df, x='OverTime', hue='turnover')
sns.countplot(ax=ax[5,1], data=df, x='PercentSalaryHike', hue='turnover')
sns.countplot(ax=ax[5,2], data=df, x='PerformanceRating', hue='turnover')

sns.countplot(ax=ax[6,0], data=df, x='RelationshipSatisfaction', hue='turnover')
sns.countplot(ax=ax[6,1], data=df, x='StockOptionLevel', hue='turnover')
sns.histplot(ax=ax[6,2], data=df, x='TotalWorkingYears', hue='turnover')

sns.countplot(ax=ax[7,0], data=df, x='TrainingTimesLastYear', hue='turnover')
sns.countplot(ax=ax[7,1], data=df, x='WorkLifeBalance', hue='turnover')
sns.histplot(ax=ax[7,2], data=df, x='YearsAtCompany', hue='turnover')

sns.countplot(ax=ax[8,0], data=df, x='YearsInCurrentRole', hue='turnover')
sns.countplot(ax=ax[8,1], data=df, x='YearsSinceLastPromotion', hue='turnover')
sns.countplot(ax=ax[8,2], data=df, x='YearsWithCurrManager', hue='turnover');

# %% [markdown]
# Pelos gráficos acima, pode-se levantar a hipótese de maior probabilidade de turnover quando o funcionário é mais jovem, tem menos tempo de casa, ganha menos, ou se sente estagnado na carreira.

# %% [markdown]
# Ao examinar os gráficos acima para 27 variáveis destaco as altas taxas de turnover para:
# - 'YearsAtCompany', de 0 a 2 anos. O mesmo parece ocorrer para 0 a 2 anos em 'YearsInCurrentRole', 'YearsSinceLastPromotion' e 'YearsWithCurrentManager'. Nesses últimos, há um pico de turnover no prazo de 2 anos que depois amortece até o sétimo ano.
# - A taxa turnover em 'TotalWorkingYears' também é relativamente alta até 10 anos.
# - 'PercentSalaryHike' e 'MonthlyIncome' também apresentam alta taxa de turnover para valores mais baixos.

# %%
f, ax = plt.subplots(2,3, figsize=(24,12))
sns.histplot(ax=ax[0,0], data=df, x='YearsAtCompany', hue='turnover')
sns.countplot(ax=ax[0,1], data=df, x='YearsInCurrentRole', hue='turnover')
sns.countplot(ax=ax[0,2], data=df, x='YearsWithCurrManager', hue='turnover')
sns.histplot(ax=ax[1,0], data=df, x='TotalWorkingYears', hue='turnover')     
sns.countplot(ax=ax[1,1], data=df, x='PercentSalaryHike', hue='turnover')     
sns.histplot(ax=ax[1,2], data=df, x='MonthlyIncome', hue='turnover');

# %% [markdown]
# - Em 'Age', parece que idade influencia demais na taxa de turnover, chegando a ficar até maior do que a taxa de retenção de funcionários.

# %%
sns.histplot(data=df, x='Age', hue='turnover');

# %% [markdown]
# ### Exercicio 2. (1 ponto)
# Faça seleção de características e selecione as 8 variáveis mais importantes. Escreva quais são elas e destaque as variáveis que estão presentes nas ideias apresentadas no exercício 1.

# %% [markdown]
# Tansformando as Colunas que tem ``dtype = object`` em dummies

# %%
list(df.select_dtypes(['object']).columns)
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
df = pd.get_dummies(df, columns=['BusinessTravel'], drop_first=True)

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df = pd.get_dummies(df, columns=['Department'], drop_first=True)

# %%
df['OverTime'].describe()
# Out:
# count     1470
# unique       2
# top         No
# freq      1054
# Name: OverTime, dtype: object

# %%
df = pd.get_dummies(df, columns=['OverTime'], drop_first=True)

# %%
df['MaritalStatus'].describe()
# Out:
# count        1470
# unique          3
# top       Married
# freq          673
# Name: MaritalStatus, dtype: object

# %%
df = pd.get_dummies(df, columns=['MaritalStatus'], drop_first=True)

# %%
df['Gender'].describe()
# Out:
# count     1470
# unique       2
# top       Male
# freq       882
# Name: Gender, dtype: object

# %%
df = pd.get_dummies(df, columns=['Gender'], drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1470 non-null   int64
#  1   DistanceFromHome                   1470 non-null   int64
#  2   Education                          1470 non-null   int64
#  3   EducationField                     1470 non-null   object
#  4   EnvironmentSatisfaction            1470 non-null   int64
#  5   JobInvolvement                     1470 non-null   int64
#  6   JobLevel                           1470 non-null   int64
#  7   JobRole                            1470 non-null   object
#  8   JobSatisfaction                    1470 non-null   int64
#  9   MonthlyIncome                      1470 non-null   int64
#  10  NumCompaniesWorked                 1470 non-null   int64
# ...

# %%
df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df.drop(['EducationField'], axis=1, inplace=True)

# %%
df['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
df.drop(['JobRole'], axis=1, inplace=True)

# %%
X = df.drop(['turnover'], axis=1)
y = df['turnover']

# %%
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.preprocessing import StandardScaler

# %%
dt = DecisionTreeClassifier(random_state=42)
X_std = StandardScaler().fit_transform(X)
selector = RFE(dt, n_features_to_select=8, step=1)
selector = selector.fit(X_std, y)

# %% [markdown]
# Abaixo, o seletor RFE.
#
# Destaca-se 'Age', 'MonthlyIncome', 'TotalWorkingYears', 'YearsSinceLastPromotion', apontados anteriormente.

# %%
X = X[X.columns[selector.support_]]
X.columns
# Out:
# Index(['Age', 'DistanceFromHome', 'EnvironmentSatisfaction', 'MonthlyIncome',
#        'NumCompaniesWorked', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsSinceLastPromotion'],
#       dtype='object')

# %%
X_std = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size = 0.3, random_state=42)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred, average='macro'))
print(recall_score(y_test, y_pred, average='macro'))
# Out:
# 0.7709750566893424
# 0.5501355013550135
# 0.5574633304572908

# %% [markdown]
# ### Exercicio 4. (1 ponto)
# Faça a representação da árvore e observe como foi realizado cada ramificação. Explique o que é GINI e quais seriam as desvantagens?

# %%
plt.figure(figsize = (21,14))
plot_tree(dt)
plt.show()

# %%
accuracy = []
precision =[]
recall = []
depth = []

for i in range(2,11):
    dt = DecisionTreeClassifier(max_depth = i, random_state=42)
    X_std = StandardScaler().fit_transform(X)
    selector = RFE(dt, n_features_to_select=8, step=1)
    selector = selector.fit(X_std, y)
    
    X = X[X.columns[selector.support_]]
    X_std = StandardScaler().fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size = 0.3, random_state=42)
    dt.fit(X_train, y_train)
    y_pred = dt.predict(X_test)
    
    depth.append(i)
    accuracy.append(accuracy_score(y_test, y_pred))
    precision.append(precision_score(y_test, y_pred, average='macro'))
    recall.append(recall_score(y_test, y_pred, average='macro'))

# %%
max_accuracy = max(accuracy)
idx_max_accuracy = accuracy.index(max_accuracy)
print(f'Profundidade da Acurácia máxima: {depth[idx_max_accuracy]}\n Acurácia: {max_accuracy}\n Precisão: {precision[idx_max_accuracy]}\n Recall: {recall[idx_max_accuracy]}')
# Out:
# Profundidade da Acurácia máxima: 3
#  Acurácia: 0.8276643990929705
#  Precisão: 0.5187747035573123
#  Recall: 0.5077868852459017

# %%
dt = DecisionTreeClassifier(max_depth = depth[idx_max_accuracy], random_state=42)
selector = RFE(dt, n_features_to_select=8, step=1)
selector = selector.fit(X, y)
X_std = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size = 0.3, random_state=42)
dt.fit(X_train, y_train)

plt.figure(figsize = (21,14))
plot_tree(dt, class_names=['0', '1'], feature_names = X.columns)
plt.show()

# %% [markdown]
# R: Gini é um parâmetro de impureza. Ele mede a probabilidade de se, aleatoriamente escolher um valor dentro de um conjunto, este valor ser o que se quer (considerando pureza) ou não (considerando impureza). Em uma cesta com 4 maçãs, teríamos 100% de chance de pegar uma maçã, portanto Gini=0, o conjunto mais puro possível. Em uma cesta de 3 maçãs e 1 laranja, o índice de Gini 25%, pois teríamos 1/4 de chance de pegar a laranja ao invés da maçã.
#
# A desvantagem do índice de Gini é que ele funciona bem para cenários em que temos variáveis categóricas objetivos e não muito bem para contínuas, sendo ótimo para decisão de testes binários. Seu valor srá sempre entre 0 <= Gini <= 1.

# %% [markdown]
# ### Exercicio 5. (3 pontos)
# Chamamos de overfitting (superajuste) a situação onde um modelo "decora" como predizer o conjunto de treino, mas tende a errar muito ao predizer o conjunto de teste. Dizemos que este modelo não generaliza, não consegue lidar com dados novos. Vimos dois modelos de diferentes estrategias de aprendizado por agrupamento durante as aulas. Qual destes modelos tem maior chance de sofrer um overfitting e por quê?

# %% [markdown]
# R: Depende das características dos dados. A árvore de decisão tende a entrar em overfitting quando a árvore é muito profunda e são usados poucos atributos. Isto porque com mais atributos a árvore tem mais informações e não é necessário muita profundidade na árvore para captar algum padrão nos dados.
#
# O outro algoritmo estudado, o KNN, tem como principal fator de overfitting, o número de clusteres K, cujo número baixo é mais propenso a overfitting, uma vez que quanto mais baixo, mais vizinhos o ponto de referência terá, resultando em predições errôneas ccom base em ruído.
#
# No caso específico deste dataset, que tem em torno de 30 atributos, a árvore não poderá ser muito profunda e por este motivo, usa-se técnicas de poda, limitanado-se assim a profundidade da árvore.
#
# O KNN neste dataset no entanto, teria uma tendencia maior de overfitting, visto que o target, que seria o 'turnover', 0 ou 1, teria K=2 e muitos parâmetros. Sem mencionar o custo computacional devido ao KNN ser um algoritmo lazy-learning em que não cria um função de predição, mas sim, o cálculo de distâncias de todo o dataset.

# %% [markdown]
# ### Exercicio 6. (1 ponto)
# Você recomendaria o seu modelo para uma empresa utilizar em seu setor de Recursos Humanos? Como você explicaria para um setor que não possui conhecimento algum sobre Ciência de Dados que um modelo com 100% de acurácia é impossível de se obter?

# %% [markdown]
# R: Não recomendaria. Porém, acurácia não é tudo.
#
# Temos ainda as métricas de precisão e recall.
#
# > A acurácia é uma boa indicação geral de como o modelo performou. Porém, pode haver situações em que ela é enganosa. Por exemplo, na criação de um modelo de identificação de fraudes em cartões de crédito, o número de casos considerados como fraude pode ser bem pequeno em relação ao número de casos considerados legais. Para colocar em números, em uma situação hipotética de 280000 casos legais e 2000 casos fraudulentos, um modelo simplório que simplesmente classifica tudo como legal obteria uma acurácia de 99,3%. Ou seja, você estaria validando como ótimo um modelo que falha em detectar fraudes.
#
# > A precisão pode ser usada em uma situação em que os Falsos Positivos são considerados mais prejudiciais que os Falsos Negativos. Por exemplo, ao classificar uma ação como um bom investimento, é necessário que o modelo esteja correto, mesmo que acabe classificando bons investimentos como maus investimentos (situação de Falso Negativo) no processo. Ou seja, o modelo deve ser preciso em suas classificações, pois a partir do momento que consideramos um investimento bom quando na verdade ele não é, uma grande perda de dinheiro pode acontecer.
#
# > O recall pode ser usada em uma situação em que os Falsos Negativos são considerados mais prejudiciais que os Falsos Positivos. Por exemplo, o modelo deve de qualquer maneira encontrar todos os pacientes doentes, mesmo que classifique alguns saudáveis como doentes (situação de Falso Positivo) no processo. Ou seja, o modelo deve ter alto recall, pois classificar pacientes doentes como saudáveis pode ser uma tragédia.
#
# > Cada métrica tem suas peculiaridades que devem ser levadas em consideração na escolha de como o modelo de classificação será avaliado. Não se deve pensar em uma como melhor ou pior que a outra de maneira geral, e sim deve-se analisar o problema e escolher a/as que melhor se adapta(m).
#
# [Fonte](https://vitorborbarodrigues.medium.com/m%C3%A9tricas-de-avalia%C3%A7%C3%A3o-acur%C3%A1cia-precis%C3%A3o-recall-quais-as-diferen%C3%A7as-c8f05e0a513c)
